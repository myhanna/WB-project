# %% [markdown]
# As we learned from the basic tutorial, in WannierBerri  calculations are done by [`Calculator`](https://wannier-berri.org/docs/calculators.html#wannierberri.calculators.Calculator)s. In this tutorial we will se how to create our own calculators.
#
# As an example let's consider anomalous Nernst conductivity ([Xiao et al. 2006 ](https://doi.org/10.1103/PhysRevLett.97.026603) ). In the zero-temperature limit $\alpha_{\alpha\beta}^{\rm ANE}$ may be obtained from
#    AHC $\sigma_{\alpha\beta}(\epsilon)^{\rm AHE}$ evaluated over a
#    dense grid of Fermi levels $\epsilon$
#
# $$
#        \alpha_{\alpha\beta}^{\rm ANE}=-\frac{1}{e}\int d\varepsilon \frac{\partial f}{\partial\varepsilon}\sigma_{\alpha\beta}(\varepsilon)\frac{\varepsilon-\mu}{T}, \label{eq:ane} \tag{1}
# $$
#
#    where $f(\varepsilon)=1/\left(1+e^\frac{\varepsilon-\mu}{k_{\rm B}T}\right)$ and the AHC is defined as a Fermi-sea integral of Berry curvature
#
# \begin{equation}
# \sigma^{\rm AHC}_{xy} = -\frac{e^2}{\hbar} \sum_n \int\frac{d\mathbf{k}}{(2\pi)^3} \Omega^n_\gamma f(\epsilon_n)
# \label{eq:ahc}\tag{2}
# \end{equation}
#
#
#    In the zero-temperature limit it reduced to
#    $$
#    \alpha_{\alpha\beta}^{\rm ANE} \propto \frac{\partial \sigma_{\alpha\beta}(\varepsilon)}{\partial \varepsilon}
#    \propto \int\frac{d\mathbf{k}}{(2\pi)^3} \Omega^n_\gamma f'(\epsilon_n) \tag{3}\label{eq:ane-ahc}
#    $$
#
#    Where we omit the dimensional factor for simplicity.
#
#    ### Thus, there are two ways of calculating ANE :
#    * via eq (\ref{eq:ane-ahc})
#    * via eq (\ref{eq:ane})
#
#    let's try eq (\ref{eq:ane-ahc}) first, because AHC is already implemented
#
#    ### Warning : this is an advanced tutorial. You something may not work from first try, you need to work with documentation to resolve the problem, but do not hesitate to ask the TA if you cannot.

# %%
# Preliminary 

# Set environment variables - not mandatory but recommended if you use Parallel()
#import os
#os.environ['OPENBLAS_NUM_THREADS'] = '1' 
#os.environ['MKL_NUM_THREADS'] = '1'


import wannierberri as wberri
import wannierberri.models
print (f"Using WannierBerri version {wberri.__version__}")
import numpy as np
import scipy
import matplotlib.pyplot as plt
from termcolor import cprint

#  This block is needed if you run this cell for a second time
#  because one cannot initiate two parallel environments at a time
try:
    parallel.shutdown()   
except NameError:
    pass

# Chiose one of the options:

parallel = wberri.Parallel(num_cpus=2)
#parallel = wberri.Parallel()  # automatic detection 
#parallel = wberri.Serial()
# Out:
# Using WannierBerri version 0.14.1
# 2023-10-27 16:12:09,514	INFO worker.py:1633 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266

# %%
# Instead of Wannier functions, we work with a Hlldane model here https://wannier-berri.org/docs/models.html

model=wberri.models.Haldane_ptb()
system = wberri.System_PythTB(model)
# Out:
# R=0 found at position(s) [[3]]
# NOT using ws_dist
# Number of wannier functions: 2
# Number of R points: 7
# Recommended size of FFT grid [3 3 1]
# Reading the system from PythTB finished successfully

# %% [markdown]
# # anomalous Hall conductivity
#
# Now, let's evaluate the AHC on a grid of Ef-points, and then take a derivtive

# %%
calculators = {}
Efermi = np.linspace(-3,3,21)
# Set a grid 
grid = wberri.Grid(system, length=30 )   # length [ Ang] ~= 2*pi/dk

calculators ["ahc"] = wberri.calculators.static.AHC(Efermi=Efermi,tetra=False,kwargs_formula={"external_terms":False})

result_run_ahc = wberri.run(system,
            grid=grid,
            calculators = calculators,
            parallel=parallel,
            adpt_num_iter=0,
            fout_name='Fe',
            restart=False,
            file_Klist="Klist_ahc.pickle",  # needed to restart a calculation in future
            print_Kpoints=False
            )
# Out:
# determining grids from NK=None (<class 'NoneType'>), NKdiv=None (<class 'NoneType'>), NKFFT=None (<class 'NoneType'>)
# length=30 was converted into NK=[35 35 30]
# Minimal symmetric FFT grid :  [3 3 1]
# The grids were set to NKdiv=[7 7 1], NKFFT=[5 5 1], NKtot=[35 35  1]
# Anomalous Hall conductivity (:math:`s^3 \cdot A^2 / (kg \cdot m^3) = S/m`)
#
#         | With Fermi sea integral Eq(11) in `Ref <https://www.nature.com/articles/s41524-021-00498-5>`__
#         | Output: :math:`O = -e^2/\hbar \int [dk] \Omega f`
#         | Instruction: :math:`j_\alpha = \sigma_{\alpha\beta} E_\beta = \epsilon_{\alpha\beta\delta} O_\delta E_\beta`
#
# Grid is regular
# The set of k points is a Grid() with NKdiv=[7 7 1], NKFFT=[5 5 1], NKtot=[35 35  1]
# generating K_list
# Done in 0.0005948543548583984 s
# excluding symmetry-equivalent K-points from initial grid
# Done in 0.00796961784362793 s
# Done in 0.008000612258911133 s
# K_list contains 49 Irreducible points(100.0%) out of initial 7x7x1=49 grid
# Done, sum of weights:1.0000000000000007
# symgroup : <wannierberri.symmetry.Group object at 0x7f068e1d0130>
# processing 49 K points : using  2 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3400>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3e50>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3940>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3d00>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3ca0>}
# time for processing     49 K-points on   2 processes:     0.8447 ; per K-point          0.0172 ; proc-sec per K-point          0.0345
# time1 =  0.0023794174194335938
# Totally processed 49 K-points

# %%
# !ls
# Out:
# Fe-ahc_iter-0000.dat  Klist_ahc.pickle
# Fe-ahc_iter-0000.npz  tutorial-wb-DIY.ipynb
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3e20>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3df0>}

# %%
# taking derivative and plotting

ef = result_run_ahc.results["ahc"].Energies[0]
ahc_z = result_run_ahc.results["ahc"].data[:,2]

# take the derivative
d_ef=ef[1]-ef[0]
d_ahc_z = (ahc_z[1:]-ahc_z[:-1])/d_ef
efnew = (ef[1:]+ef[:-1])/2

plt.plot(efnew, d_ahc_z)

# %% [markdown]
# # Look into documentation
#
# Look into documentation to see how the AHC calculator is defined : press the "source" link on
# https://wannier-berri.org/docs/calculators.html
#
# One can see that it is based on the StaticCalculator, and only redefines the `__init__` method.
# Namely, it redefines formula that stands under the integral (Berry curvature) and `fder=0` meaning that the formula is weighted by the 0th derivative of the Fermi distribution.
#
# copy the definition of AHC calculator and redefine the and below and define the __init__ class
#
#
# (hint : leave the factor the same, for simplicity)
# (hint : formula shouldbe imported from here : https://wannier-berri.org/docs/formula.html#wannierberri.formula.covariant.DerOmega )

# %%
from wannierberri.calculators.static import StaticCalculator
from wannierberri.formula.covariant import Omega
from wannierberri import __factors as factors

class ANE(StaticCalculator):
    r"""Anomalous Nernst conductivity"""
    def __init__(self, constant_factor=1, **kwargs):
        self.Formula = Omega
        self.fder = 1
        super().__init__(constant_factor=constant_factor, **kwargs)


# class ANE(StaticCalculator):
#     r"""Anomalous Nernst conductivity"""
# 
#     def __init__(self, Efermi, tetra=False, **kwargs):
#         self.Efermi = Efermi
#         self.tetra = tetra
#         self.Formula = DerOmega
#         self.fder = 0     
#         super().__init__(Efermi=Efermi, **kwargs)
# 
#     def f(self, epsilon):
#         kB = 8.617333262145e-5  # eV/K
#         return 1.0 / (1.0 + np.exp((epsilon - self.Efermi) / (kB * self.temperature)))
# 
#     def df(self, epsilon):
#         kB = 8.617333262145e-5  # eV/K
#         f_val = self.f(epsilon)
#         return -f_val * (1 - f_val) / (kB * self.temperature)
# 
#     def __call__(self, epsilon_grid):
#         ahc = AHC()
#         integral = 0
#         for epsilon in epsilon_grid:
#             integral += self.df(epsilon) * ahc(epsilon) * (epsilon - self.Efermi) / self.temperature
#         return -integral / factors.e

# %% [markdown]
# ### Evaluate ANE  using the new calculator and plot the result

# %%
# insert the needed code below

calculators = {}
Efermi = np.linspace(12,13,101)
# Set a grid 
grid = wberri.Grid(system, length=50 )   # length [ Ang] ~= 2*pi/dk

calculators ["ane"] = ANE(Efermi=Efermi,tetra=True)

result_run_ane = wberri.run(system,
            grid=grid,
            calculators = calculators,
            parallel=parallel,
            adpt_num_iter=0,
            fout_name='Fe',
            restart=False,
           # file_Klist="Klist_ahc.pickle"  # needed to restart a calculation in future
            )
# Out:
# determining grids from NK=None (<class 'NoneType'>), NKdiv=None (<class 'NoneType'>), NKFFT=None (<class 'NoneType'>)
# length=50 was converted into NK=[58 58 50]
# Minimal symmetric FFT grid :  [3 3 1]
# WARNING : the requested k-grid [58 58 50] was adjusted to [57 57 50].
# The grids were set to NKdiv=[19 19  1], NKFFT=[3 3 1], NKtot=[57 57  1]
# Anomalous Nernst conductivity
#
# Grid is regular
# The set of k points is a Grid() with NKdiv=[19 19  1], NKFFT=[3 3 1], NKtot=[57 57  1]
# generating K_list
# Done in 0.00374603271484375 s
# excluding symmetry-equivalent K-points from initial grid
# Done in 0.015067577362060547 s
# Done in 0.01512598991394043 s
# K_list contains 361 Irreducible points(100.0%) out of initial 19x19x1=361 grid
# Done, sum of weights:0.999999999999993
# iteration 0 - 361 points. New points are:
#  K-point 0 : coord in rec.lattice = [   0.000000  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 1 : coord in rec.lattice = [   0.000000  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 2 : coord in rec.lattice = [   0.000000  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 3 : coord in rec.lattice = [   0.000000  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 4 : coord in rec.lattice = [   0.000000  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 5 : coord in rec.lattice = [   0.000000  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 6 : coord in rec.lattice = [   0.000000  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 7 : coord in rec.lattice = [   0.000000  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 8 : coord in rec.lattice = [   0.000000  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 9 : coord in rec.lattice = [   0.000000  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 10 : coord in rec.lattice = [   0.000000  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 11 : coord in rec.lattice = [   0.000000  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 12 : coord in rec.lattice = [   0.000000  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 13 : coord in rec.lattice = [   0.000000  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 14 : coord in rec.lattice = [   0.000000  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 15 : coord in rec.lattice = [   0.000000  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 16 : coord in rec.lattice = [   0.000000  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 17 : coord in rec.lattice = [   0.000000  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 18 : coord in rec.lattice = [   0.000000  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 19 : coord in rec.lattice = [   0.052632  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 20 : coord in rec.lattice = [   0.052632  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 21 : coord in rec.lattice = [   0.052632  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 22 : coord in rec.lattice = [   0.052632  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 23 : coord in rec.lattice = [   0.052632  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 24 : coord in rec.lattice = [   0.052632  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 25 : coord in rec.lattice = [   0.052632  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 26 : coord in rec.lattice = [   0.052632  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 27 : coord in rec.lattice = [   0.052632  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 28 : coord in rec.lattice = [   0.052632  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 29 : coord in rec.lattice = [   0.052632  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 30 : coord in rec.lattice = [   0.052632  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 31 : coord in rec.lattice = [   0.052632  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 32 : coord in rec.lattice = [   0.052632  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 33 : coord in rec.lattice = [   0.052632  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 34 : coord in rec.lattice = [   0.052632  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 35 : coord in rec.lattice = [   0.052632  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 36 : coord in rec.lattice = [   0.052632  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 37 : coord in rec.lattice = [   0.052632  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 38 : coord in rec.lattice = [   0.105263  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 39 : coord in rec.lattice = [   0.105263  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 40 : coord in rec.lattice = [   0.105263  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 41 : coord in rec.lattice = [   0.105263  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 42 : coord in rec.lattice = [   0.105263  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 43 : coord in rec.lattice = [   0.105263  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 44 : coord in rec.lattice = [   0.105263  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 45 : coord in rec.lattice = [   0.105263  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 46 : coord in rec.lattice = [   0.105263  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 47 : coord in rec.lattice = [   0.105263  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 48 : coord in rec.lattice = [   0.105263  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 49 : coord in rec.lattice = [   0.105263  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 50 : coord in rec.lattice = [   0.105263  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 51 : coord in rec.lattice = [   0.105263  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 52 : coord in rec.lattice = [   0.105263  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 53 : coord in rec.lattice = [   0.105263  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 54 : coord in rec.lattice = [   0.105263  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 55 : coord in rec.lattice = [   0.105263  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 56 : coord in rec.lattice = [   0.105263  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 57 : coord in rec.lattice = [   0.157895  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 58 : coord in rec.lattice = [   0.157895  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 59 : coord in rec.lattice = [   0.157895  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 60 : coord in rec.lattice = [   0.157895  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 61 : coord in rec.lattice = [   0.157895  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 62 : coord in rec.lattice = [   0.157895  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 63 : coord in rec.lattice = [   0.157895  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 64 : coord in rec.lattice = [   0.157895  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 65 : coord in rec.lattice = [   0.157895  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 66 : coord in rec.lattice = [   0.157895  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 67 : coord in rec.lattice = [   0.157895  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 68 : coord in rec.lattice = [   0.157895  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 69 : coord in rec.lattice = [   0.157895  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 70 : coord in rec.lattice = [   0.157895  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 71 : coord in rec.lattice = [   0.157895  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 72 : coord in rec.lattice = [   0.157895  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 73 : coord in rec.lattice = [   0.157895  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 74 : coord in rec.lattice = [   0.157895  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 75 : coord in rec.lattice = [   0.157895  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 76 : coord in rec.lattice = [   0.210526  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 77 : coord in rec.lattice = [   0.210526  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 78 : coord in rec.lattice = [   0.210526  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 79 : coord in rec.lattice = [   0.210526  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 80 : coord in rec.lattice = [   0.210526  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 81 : coord in rec.lattice = [   0.210526  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 82 : coord in rec.lattice = [   0.210526  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 83 : coord in rec.lattice = [   0.210526  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 84 : coord in rec.lattice = [   0.210526  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 85 : coord in rec.lattice = [   0.210526  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 86 : coord in rec.lattice = [   0.210526  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 87 : coord in rec.lattice = [   0.210526  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 88 : coord in rec.lattice = [   0.210526  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 89 : coord in rec.lattice = [   0.210526  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 90 : coord in rec.lattice = [   0.210526  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 91 : coord in rec.lattice = [   0.210526  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 92 : coord in rec.lattice = [   0.210526  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 93 : coord in rec.lattice = [   0.210526  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 94 : coord in rec.lattice = [   0.210526  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 95 : coord in rec.lattice = [   0.263158  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 96 : coord in rec.lattice = [   0.263158  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 97 : coord in rec.lattice = [   0.263158  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 98 : coord in rec.lattice = [   0.263158  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 99 : coord in rec.lattice = [   0.263158  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 100 : coord in rec.lattice = [   0.263158  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 101 : coord in rec.lattice = [   0.263158  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 102 : coord in rec.lattice = [   0.263158  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 103 : coord in rec.lattice = [   0.263158  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 104 : coord in rec.lattice = [   0.263158  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 105 : coord in rec.lattice = [   0.263158  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 106 : coord in rec.lattice = [   0.263158  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 107 : coord in rec.lattice = [   0.263158  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 108 : coord in rec.lattice = [   0.263158  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 109 : coord in rec.lattice = [   0.263158  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 110 : coord in rec.lattice = [   0.263158  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 111 : coord in rec.lattice = [   0.263158  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 112 : coord in rec.lattice = [   0.263158  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 113 : coord in rec.lattice = [   0.263158  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 114 : coord in rec.lattice = [   0.315789  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 115 : coord in rec.lattice = [   0.315789  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 116 : coord in rec.lattice = [   0.315789  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 117 : coord in rec.lattice = [   0.315789  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 118 : coord in rec.lattice = [   0.315789  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 119 : coord in rec.lattice = [   0.315789  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 120 : coord in rec.lattice = [   0.315789  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 121 : coord in rec.lattice = [   0.315789  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 122 : coord in rec.lattice = [   0.315789  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 123 : coord in rec.lattice = [   0.315789  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 124 : coord in rec.lattice = [   0.315789  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 125 : coord in rec.lattice = [   0.315789  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 126 : coord in rec.lattice = [   0.315789  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 127 : coord in rec.lattice = [   0.315789  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 128 : coord in rec.lattice = [   0.315789  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 129 : coord in rec.lattice = [   0.315789  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 130 : coord in rec.lattice = [   0.315789  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 131 : coord in rec.lattice = [   0.315789  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 132 : coord in rec.lattice = [   0.315789  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 133 : coord in rec.lattice = [   0.368421  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 134 : coord in rec.lattice = [   0.368421  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 135 : coord in rec.lattice = [   0.368421  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 136 : coord in rec.lattice = [   0.368421  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 137 : coord in rec.lattice = [   0.368421  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 138 : coord in rec.lattice = [   0.368421  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 139 : coord in rec.lattice = [   0.368421  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 140 : coord in rec.lattice = [   0.368421  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 141 : coord in rec.lattice = [   0.368421  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 142 : coord in rec.lattice = [   0.368421  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 143 : coord in rec.lattice = [   0.368421  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 144 : coord in rec.lattice = [   0.368421  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 145 : coord in rec.lattice = [   0.368421  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 146 : coord in rec.lattice = [   0.368421  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 147 : coord in rec.lattice = [   0.368421  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 148 : coord in rec.lattice = [   0.368421  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 149 : coord in rec.lattice = [   0.368421  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 150 : coord in rec.lattice = [   0.368421  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 151 : coord in rec.lattice = [   0.368421  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 152 : coord in rec.lattice = [   0.421053  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 153 : coord in rec.lattice = [   0.421053  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 154 : coord in rec.lattice = [   0.421053  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 155 : coord in rec.lattice = [   0.421053  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 156 : coord in rec.lattice = [   0.421053  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 157 : coord in rec.lattice = [   0.421053  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 158 : coord in rec.lattice = [   0.421053  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 159 : coord in rec.lattice = [   0.421053  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 160 : coord in rec.lattice = [   0.421053  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 161 : coord in rec.lattice = [   0.421053  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 162 : coord in rec.lattice = [   0.421053  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 163 : coord in rec.lattice = [   0.421053  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 164 : coord in rec.lattice = [   0.421053  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 165 : coord in rec.lattice = [   0.421053  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 166 : coord in rec.lattice = [   0.421053  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 167 : coord in rec.lattice = [   0.421053  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 168 : coord in rec.lattice = [   0.421053  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 169 : coord in rec.lattice = [   0.421053  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 170 : coord in rec.lattice = [   0.421053  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 171 : coord in rec.lattice = [   0.473684  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 172 : coord in rec.lattice = [   0.473684  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 173 : coord in rec.lattice = [   0.473684  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 174 : coord in rec.lattice = [   0.473684  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 175 : coord in rec.lattice = [   0.473684  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 176 : coord in rec.lattice = [   0.473684  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 177 : coord in rec.lattice = [   0.473684  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 178 : coord in rec.lattice = [   0.473684  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 179 : coord in rec.lattice = [   0.473684  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 180 : coord in rec.lattice = [   0.473684  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 181 : coord in rec.lattice = [   0.473684  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 182 : coord in rec.lattice = [   0.473684  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 183 : coord in rec.lattice = [   0.473684  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 184 : coord in rec.lattice = [   0.473684  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 185 : coord in rec.lattice = [   0.473684  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 186 : coord in rec.lattice = [   0.473684  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 187 : coord in rec.lattice = [   0.473684  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 188 : coord in rec.lattice = [   0.473684  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 189 : coord in rec.lattice = [   0.473684  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 190 : coord in rec.lattice = [   0.526316  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 191 : coord in rec.lattice = [   0.526316  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 192 : coord in rec.lattice = [   0.526316  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 193 : coord in rec.lattice = [   0.526316  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 194 : coord in rec.lattice = [   0.526316  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 195 : coord in rec.lattice = [   0.526316  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 196 : coord in rec.lattice = [   0.526316  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 197 : coord in rec.lattice = [   0.526316  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 198 : coord in rec.lattice = [   0.526316  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 199 : coord in rec.lattice = [   0.526316  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 200 : coord in rec.lattice = [   0.526316  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 201 : coord in rec.lattice = [   0.526316  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 202 : coord in rec.lattice = [   0.526316  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 203 : coord in rec.lattice = [   0.526316  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 204 : coord in rec.lattice = [   0.526316  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 205 : coord in rec.lattice = [   0.526316  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 206 : coord in rec.lattice = [   0.526316  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 207 : coord in rec.lattice = [   0.526316  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 208 : coord in rec.lattice = [   0.526316  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 209 : coord in rec.lattice = [   0.578947  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 210 : coord in rec.lattice = [   0.578947  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 211 : coord in rec.lattice = [   0.578947  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 212 : coord in rec.lattice = [   0.578947  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 213 : coord in rec.lattice = [   0.578947  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 214 : coord in rec.lattice = [   0.578947  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 215 : coord in rec.lattice = [   0.578947  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 216 : coord in rec.lattice = [   0.578947  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 217 : coord in rec.lattice = [   0.578947  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 218 : coord in rec.lattice = [   0.578947  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 219 : coord in rec.lattice = [   0.578947  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 220 : coord in rec.lattice = [   0.578947  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 221 : coord in rec.lattice = [   0.578947  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 222 : coord in rec.lattice = [   0.578947  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 223 : coord in rec.lattice = [   0.578947  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 224 : coord in rec.lattice = [   0.578947  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 225 : coord in rec.lattice = [   0.578947  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 226 : coord in rec.lattice = [   0.578947  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 227 : coord in rec.lattice = [   0.578947  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 228 : coord in rec.lattice = [   0.631579  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 229 : coord in rec.lattice = [   0.631579  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 230 : coord in rec.lattice = [   0.631579  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 231 : coord in rec.lattice = [   0.631579  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 232 : coord in rec.lattice = [   0.631579  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 233 : coord in rec.lattice = [   0.631579  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 234 : coord in rec.lattice = [   0.631579  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 235 : coord in rec.lattice = [   0.631579  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 236 : coord in rec.lattice = [   0.631579  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 237 : coord in rec.lattice = [   0.631579  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 238 : coord in rec.lattice = [   0.631579  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 239 : coord in rec.lattice = [   0.631579  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 240 : coord in rec.lattice = [   0.631579  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 241 : coord in rec.lattice = [   0.631579  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 242 : coord in rec.lattice = [   0.631579  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 243 : coord in rec.lattice = [   0.631579  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 244 : coord in rec.lattice = [   0.631579  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 245 : coord in rec.lattice = [   0.631579  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 246 : coord in rec.lattice = [   0.631579  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 247 : coord in rec.lattice = [   0.684211  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 248 : coord in rec.lattice = [   0.684211  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 249 : coord in rec.lattice = [   0.684211  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 250 : coord in rec.lattice = [   0.684211  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 251 : coord in rec.lattice = [   0.684211  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 252 : coord in rec.lattice = [   0.684211  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 253 : coord in rec.lattice = [   0.684211  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 254 : coord in rec.lattice = [   0.684211  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 255 : coord in rec.lattice = [   0.684211  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 256 : coord in rec.lattice = [   0.684211  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 257 : coord in rec.lattice = [   0.684211  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 258 : coord in rec.lattice = [   0.684211  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 259 : coord in rec.lattice = [   0.684211  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 260 : coord in rec.lattice = [   0.684211  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 261 : coord in rec.lattice = [   0.684211  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 262 : coord in rec.lattice = [   0.684211  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 263 : coord in rec.lattice = [   0.684211  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 264 : coord in rec.lattice = [   0.684211  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 265 : coord in rec.lattice = [   0.684211  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 266 : coord in rec.lattice = [   0.736842  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 267 : coord in rec.lattice = [   0.736842  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 268 : coord in rec.lattice = [   0.736842  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 269 : coord in rec.lattice = [   0.736842  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 270 : coord in rec.lattice = [   0.736842  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 271 : coord in rec.lattice = [   0.736842  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 272 : coord in rec.lattice = [   0.736842  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 273 : coord in rec.lattice = [   0.736842  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 274 : coord in rec.lattice = [   0.736842  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 275 : coord in rec.lattice = [   0.736842  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
# ...
#  K-point 304 : coord in rec.lattice = [   0.842105  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 305 : coord in rec.lattice = [   0.842105  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 306 : coord in rec.lattice = [   0.842105  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 307 : coord in rec.lattice = [   0.842105  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 308 : coord in rec.lattice = [   0.842105  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 309 : coord in rec.lattice = [   0.842105  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 310 : coord in rec.lattice = [   0.842105  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 311 : coord in rec.lattice = [   0.842105  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 312 : coord in rec.lattice = [   0.842105  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 313 : coord in rec.lattice = [   0.842105  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 314 : coord in rec.lattice = [   0.842105  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 315 : coord in rec.lattice = [   0.842105  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 316 : coord in rec.lattice = [   0.842105  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 317 : coord in rec.lattice = [   0.842105  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 318 : coord in rec.lattice = [   0.842105  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 319 : coord in rec.lattice = [   0.842105  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 320 : coord in rec.lattice = [   0.842105  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 321 : coord in rec.lattice = [   0.842105  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 322 : coord in rec.lattice = [   0.842105  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 323 : coord in rec.lattice = [   0.894737  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 324 : coord in rec.lattice = [   0.894737  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 325 : coord in rec.lattice = [   0.894737  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 326 : coord in rec.lattice = [   0.894737  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 327 : coord in rec.lattice = [   0.894737  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 328 : coord in rec.lattice = [   0.894737  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 329 : coord in rec.lattice = [   0.894737  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 330 : coord in rec.lattice = [   0.894737  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 331 : coord in rec.lattice = [   0.894737  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 332 : coord in rec.lattice = [   0.894737  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 333 : coord in rec.lattice = [   0.894737  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 334 : coord in rec.lattice = [   0.894737  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 335 : coord in rec.lattice = [   0.894737  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 336 : coord in rec.lattice = [   0.894737  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 337 : coord in rec.lattice = [   0.894737  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 338 : coord in rec.lattice = [   0.894737  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 339 : coord in rec.lattice = [   0.894737  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 340 : coord in rec.lattice = [   0.894737  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 341 : coord in rec.lattice = [   0.894737  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 342 : coord in rec.lattice = [   0.947368  ,   0.000000 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 343 : coord in rec.lattice = [   0.947368  ,   0.052632 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 344 : coord in rec.lattice = [   0.947368  ,   0.105263 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 345 : coord in rec.lattice = [   0.947368  ,   0.157895 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 346 : coord in rec.lattice = [   0.947368  ,   0.210526 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 347 : coord in rec.lattice = [   0.947368  ,   0.263158 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 348 : coord in rec.lattice = [   0.947368  ,   0.315789 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 349 : coord in rec.lattice = [   0.947368  ,   0.368421 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 350 : coord in rec.lattice = [   0.947368  ,   0.421053 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 351 : coord in rec.lattice = [   0.947368  ,   0.473684 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 352 : coord in rec.lattice = [   0.947368  ,   0.526316 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 353 : coord in rec.lattice = [   0.947368  ,   0.578947 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 354 : coord in rec.lattice = [   0.947368  ,   0.631579 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 355 : coord in rec.lattice = [   0.947368  ,   0.684211 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 356 : coord in rec.lattice = [   0.947368  ,   0.736842 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 357 : coord in rec.lattice = [   0.947368  ,   0.789474 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 358 : coord in rec.lattice = [   0.947368  ,   0.842105 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 359 : coord in rec.lattice = [   0.947368  ,   0.894737 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
#  K-point 360 : coord in rec.lattice = [   0.947368  ,   0.947368 ,    0.000000 ], refinement level:0, factor = 0.002770083102493075dK=[0.05263158 0.05263158 1.        ]
# symgroup : <wannierberri.symmetry.Group object at 0x7f068e1d0130>
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3e80>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3790>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3dc0>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3820>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3e80>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3790>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3dc0>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3820>}
# (paralfunc pid=2881) {'Kpoint': <wannierberri.grid.__Kpoint.KpointBZparallel object at 0x7fb1b88c3e80>}
# processing 361 K points : using  2 processes.
# # K-points calculated  Wall time (sec)  Est. remaining (sec)
# ---------------------------------------------------------------------------
# RayTaskError(ValueError)                  Traceback (most recent call last)
# Cell In[7], line 10
#       6 grid = wberri.Grid(system, length=50 )   # length [ Ang] ~= 2*pi/dk
#       8 calculators ["ane"] = ANE(Efermi=Efermi,tetra=True)
# ---> 10 result_run_ane = wberri.run(system,
#      11             grid=grid,
#      12             calculators = calculators,
#      13             parallel=parallel,
#      14             adpt_num_iter=0,
#      15             fout_name='Fe',
#      16             restart=False,
#      17            # file_Klist="Klist_ahc.pickle"  # needed to restart a calculation in future
#      18             )
#
# File ~/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/run.py:304, in run(system, grid, calculators, adpt_num_iter, use_irred_kpt, symmetrize, fout_name, suffix, parameters_K, file_Klist, restart, Klist_part, parallel, print_Kpoints, adpt_mesh, adpt_fac, fast_iter, print_progress_step)
#     302         if not K.evaluated:
#     303             print(" K-point {0} : {1} ".format(i, K))
# --> 304 counter += process(
#     305     paralfunc,
#     306     K_list,
#     307     parallel,
#     308     symgroup=system.symgroup if symmetrize else None,
#     309     print_progress_step=print_progress_step,
#     310     remote_parameters=remote_parameters)
#     312 nk = len(K_list)
#     313 try:
#
# File ~/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/run.py:81, in process(paralfunc, K_list, parallel, symgroup, remote_parameters, print_progress_step)
#      79             break
#      80         t_print_prev = print_progress(num_remotes_calculated, numK, t0, t_print_prev, print_progress_step)
# ---> 81     res = parallel.ray.get(remotes)
#      82 else:
#      83     raise RuntimeError(f"unsupported parallel method : '{parallel.method}'")
#
# File ~/WannierBerri-project/wannierberri/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/WannierBerri-project/wannierberri/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/WannierBerri-project/wannierberri/lib/python3.10/site-packages/ray/_private/worker.py:2547, in get(object_refs, timeout)
#    2545     worker.core_worker.dump_object_store_memory_usage()
#    2546 if isinstance(value, RayTaskError):
# -> 2547     raise value.as_instanceof_cause()
#    2548 else:
#    2549     raise value
#
# RayTaskError(ValueError): ray::paralfunc() (pid=2881, ip=172.20.202.62)
# KeyError: 'AA'
#
# During handling of the above exception, another exception occurred:
#
# ray::paralfunc() (pid=2881, ip=172.20.202.62)
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/system/system.py", line 163, in get_R_mat
#     return self._XX_R[key]
# KeyError: 'AA'
#
# During handling of the above exception, another exception occurred:
#
# ray::paralfunc() (pid=2881, ip=172.20.202.62)
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/run.py", line 211, in paralfunc
#     return ResultDict({k: v(data) for k, v in _calculators.items()})
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/run.py", line 211, in <dictcomp>
#     return ResultDict({k: v(data) for k, v in _calculators.items()})
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/calculators/static.py", line 52, in __call__
#     formula = self.Formula(data_K, **self.kwargs_formula)
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/formula/covariant.py", line 133, in __init__
#     self.A = data_K.covariant('AA')
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/data_K.py", line 270, in covariant
#     self.Xbar(name, commader),
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/data_K.py", line 453, in Xbar
#     self.get_R_mat(name).copy(), der=der, hermitean=(name in ['AA', 'SS', 'OO']))
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/data_K.py", line 412, in get_R_mat
#     X_R = self.system.get_R_mat(key)
#   File "/home/myhanna/WannierBerri-project/wannierberri/lib/python3.10/site-packages/wannierberri/system/system.py", line 165, in get_R_mat
#     raise ValueError(f"The real-space matrix elements '{key}' are not set in the system,"+
# ValueError: The real-space matrix elements 'AA' are not set in the system, but are required for the current calculation. please check parameters of the System() initializer

# %%
ef = result_run_ane.results["ane"].Energies[0]
ane_z = result_run_ane.results["ane"].dataSmooth[:,2]


plt.scatter(efnew,d_ahc_z)
plt.plot(ef, ane_z)
plt.show()

# %% [markdown]
# # Questions:
#
# 1. Make the k-points or Efermi denser. Will the agreement improve?
#
# 2. we calculated the AHC and ANE with zero refinement iterations, and the results matched well (or at least they should). If we calculate them separately, but with some refinement iterations, will the results match?
#
# 3. What if we use refinement itrations and run the two calculations together, in one `run()` call ?

# %% [markdown]
# # FormulaProduct
#
# Look at the definition of erryDipole_FermiSurf
#
# https://wannier-berri.org/_modules/wannierberri/calculators/static.html
#
#
# It evaluates
#
# \begin{equation}
# D_{ab} =\sum_n \int\frac{d\mathbf{k}}{(2\pi)^3} v_a\Omega^n_b f(\epsilon_n)
# \label{eq:ahc}\tag{2}
# \end{equation}
#
# also look at definition of the Feormula https://wannier-berri.org/docs/formula.html
#
# you can see that it is base on a FormulaProduct.  Essentially, by analogy you may define any tensor, e.g.
#
# $$
# \sum_n \int\frac{d\mathbf{k}}{(2\pi)^3} v_a\Omega^n_b v_c f''(\epsilon_n)
# $$
#
# i.e. product of several quantities weighted by rge second derivative of Fermi distribution. You may write any analogous formula, if you want. Try to define corresponding FormulaProduct and StaticCalculator classes, and try to evaluate them.

# %% [markdown]
# # Problem for a prize:
#
# ### who solves first, gets a bottle of local wine (or smth sweet, if you do not drink)
#
# for a bottle of wine : try to prove (analytically and numerically) that
#
# $$
# \sum_n \int\frac{d\mathbf{k}}{(2\pi)^3} \partial_a \partial_b \partial_c \epsilon_{n\mathbf{k}} f(\epsilon_{n\mathbf{k}}) \propto \sum_n \int\frac{d\mathbf{k}}{(2\pi)^3} \partial_a \epsilon_{n\mathbf{k}}  \partial_b \epsilon_{n\mathbf{k}}  \partial_c \epsilon_{n\mathbf{k}} f''(\epsilon_{n\mathbf{k}})
# $$
#
# and tell me what is the factor missing?
#
#
# # Have fun !
